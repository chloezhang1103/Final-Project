# %% [markdown]
# # Data Cleaning
# We first deal with the data we scraped from google map.(credit by https://apify.com/)

# %%
import json

file_path = "data/dataset_crawler-google-places_2024-12-16_02-57-12-340.json"

with open(file_path, 'r') as f:
    data = json.load(f)

print(type(data)) 
print(len(data))   
print(data[0])
# Out:
# <class 'list'>
# 180
# {'searchString': 'Michelin restaurants NYC', 'rank': 31, 'searchPageUrl': 'https://www.google.com/maps/search/Michelin%20restaurants%20NYC/@40.619187165763144,-74.04782588816352,15z?hl=en', 'searchPageLoadedUrl': None, 'isAdvertisement': False, 'title': 'Phil-Am Kusina', 'subTitle': None, 'description': 'Casual restaurant cooking up traditional Filipino dishes with a modern twist.', 'price': '$10–20', 'categoryName': 'Filipino restaurant', 'address': '556 Tompkins Ave., Staten Island, NY 10305', 'neighborhood': 'Rosebank', 'street': '556 Tompkins Ave.', 'city': 'Staten Island', 'postalCode': '10305', 'state': 'New York', 'countryCode': 'US', 'website': 'http://www.philamkusina.com/', 'phone': '(718) 727-3663', 'phoneUnformatted': '+17187273663', 'claimThisBusiness': False, 'location': {'lat': 40.6124623, 'lng': -74.071427}, 'locatedIn': None, 'plusCode': 'JW6H+XC Staten Island, New York', 'menu': None, 'totalScore': 4.7, 'permanentlyClosed': False, 'temporarilyClosed': False, 'placeId': 'ChIJDYD92atPwokRlN30x0vubIk', 'categories': ['Filipino restaurant'], 'fid': '0x89c24fabd9fd800d:0x896cee4bc7f4dd94', 'cid': '9902551689925549460', 'reviewsCount': 320, 'reviewsDistribution': {'oneStar': 6, 'twoStar': 4, 'threeStar': 8, 'fourStar': 53, 'fiveStar': 249}, 'imagesCount': 487, 'imageCategories': ['All', 'Menu', 'Videos', 'Food & drink', 'Vibe', 'Halo-halo', 'Short ribs', 'Spring roll', 'By owner', 'Street View & 360°'], 'scrapedAt': '2024-12-16T02:34:38.457Z', 'reserveTableUrl': None, 'googleFoodUrl': None, 'hotelStars': None, 'hotelDescription': None, 'checkInDate': None, 'checkOutDate': None, 'similarHotelsNearby': None, 'hotelReviewSummary': None, 'hotelAds': [], 'popularTimesLiveText': None, 'popularTimesLivePercent': None, 'popularTimesHistogram': {'Su': [{'hour': 6, 'occupancyPercent': 0}, {'hour': 7, 'occupancyPercent': 0}, {'hour': 8, 'occupancyPercent': 0}, {'hour': 9, 'occupancyPercent': 0}, {'hour': 10, 'occupancyPercent': 0}, {'hour': 11, 'occupancyPercent': 50}, {'hour': 12, 'occupancyPercent': 87}, {'hour': 13, 'occupancyPercent': 75}, {'hour': 14, 'occupancyPercent': 100}, {'hour': 15, 'occupancyPercent': 79}, {'hour': 16, 'occupancyPercent': 83}, {'hour': 17, 'occupancyPercent': 87}, {'hour': 18, 'occupancyPercent': 95}, {'hour': 19, 'occupancyPercent': 0}, {'hour': 20, 'occupancyPercent': 0}, {'hour': 21, 'occupancyPercent': 0}, {'hour': 22, 'occupancyPercent': 0}, {'hour': 23, 'occupancyPercent': 0}], 'Mo': [], 'Tu': [{'hour': 6, 'occupancyPercent': 0}, {'hour': 7, 'occupancyPercent': 0}, {'hour': 8, 'occupancyPercent': 0}, {'hour': 9, 'occupancyPercent': 0}, {'hour': 10, 'occupancyPercent': 0}, {'hour': 11, 'occupancyPercent': 0}, {'hour': 12, 'occupancyPercent': 0}, {'hour': 13, 'occupancyPercent': 0}, {'hour': 14, 'occupancyPercent': 0}, {'hour': 15, 'occupancyPercent': 45}, {'hour': 16, 'occupancyPercent': 58}, {'hour': 17, 'occupancyPercent': 37}, {'hour': 18, 'occupancyPercent': 25}, {'hour': 19, 'occupancyPercent': 20}, {'hour': 20, 'occupancyPercent': 0}, {'hour': 21, 'occupancyPercent': 0}, {'hour': 22, 'occupancyPercent': 0}, {'hour': 23, 'occupancyPercent': 0}], 'We': [{'hour': 6, 'occupancyPercent': 0}, {'hour': 7, 'occupancyPercent': 0}, {'hour': 8, 'occupancyPercent': 0}, {'hour': 9, 'occupancyPercent': 0}, {'hour': 10, 'occupancyPercent': 0}, {'hour': 11, 'occupancyPercent': 0}, {'hour': 12, 'occupancyPercent': 0}, {'hour': 13, 'occupancyPercent': 0}, {'hour': 14, 'occupancyPercent': 0}, {'hour': 15, 'occupancyPercent': 91}, {'hour': 16, 'occupancyPercent': 75}, {'hour': 17, 'occupancyPercent': 70}, {'hour': 18, 'occupancyPercent': 50}, {'hour': 19, 'occupancyPercent': 62}, {'hour': 20, 'occupancyPercent': 0}, {'hour': 21, 'occupancyPercent': 0}, {'hour': 22, 'occupancyPercent': 0}, {'hour': 23, 'occupancyPercent': 0}], 'Th': [{'hour': 6, 'occupancyPercent': 0}, {'hour': 7, 'occupancyPercent': 0}, {'hour': 8, 'occupancyPercent': 0}, {'hour': 9, 'occupancyPercent': 0}, {'hour': 10, 'occupancyPercent' ...

# %% [markdown]
# ## Convert JSON data to a DataFrame

# %%
import pandas as pd

df = pd.DataFrame(data)

print(df.head())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                  searchString  rank  \
# 0                    Michelin restaurants NYC    31
# 1  Michelin-starred restaurants New York City    32
# 2  Michelin-starred restaurants New York City    29
# 3                    Michelin restaurants NYC    88
# 4                    Michelin restaurants NYC    86
#
#                                        searchPageUrl searchPageLoadedUrl  \
# 0  https://www.google.com/maps/search/Michelin%20...                None
# 1  https://www.google.com/maps/search/Michelin-st...                None
# 2  https://www.google.com/maps/search/Michelin-st...                None
# 3  https://www.google.com/maps/search/Michelin%20...                None
# 4  https://www.google.com/maps/search/Michelin%20...                None
#
#    isAdvertisement                     title subTitle  \
# 0            False            Phil-Am Kusina     None
# 1            False              H & L Bagels     None
# 2            False        Coszcal De Allende     None
# 3            False                    E.A.T.     None
# 4            False  Dowling's at The Carlyle     None
#
#                                          description   price  \
# 0  Casual restaurant cooking up traditional Filip...  $10–20
# 1                                               None   $1–10
# 2                                               None  $30–50
# 3  Counter-serve outlet for breakfast and coffee,...  $30–50
# 4                                               None   $100+
#
#           categoryName  ... parentPlaceUrl  \
# 0  Filipino restaurant  ...           None
# 1           Bagel shop  ...           None
# 2   Mexican restaurant  ...           None
# 3  American restaurant  ...           None
# 4           Restaurant  ...           None
#
#                                tableReservationLinks bookingLinks  \
# 0                                                 []           []
# 1                                                 []           []
# 2  [{'name': 'resy.com', 'url': 'https://resy.com...           []
# 3                                                 []           []
# 4  [{'name': 'resy.com', 'url': 'https://resy.com...           []
#
#                                              orderBy images  \
# 0  [{'name': 'Seamless', 'orderUrl': 'https://www...   None
# 1                                                 []   None
# 2  [{'name': 'Toast Online Ordering', 'orderUrl':...   None
# 3  [{'name': 'Storefront by DoorDash', 'orderUrl'...   None
# 4                                                 []   None
#
#                                            imageUrls  \
# 0  [https://lh5.googleusercontent.com/p/AF1QipOVC...
# 1  [https://lh5.googleusercontent.com/p/AF1QipNTR...
# 2  [https://lh5.googleusercontent.com/p/AF1QipNn8...
# 3  [https://lh5.googleusercontent.com/p/AF1QipMY0...
# 4  [https://lh5.googleusercontent.com/p/AF1QipPws...
#
#                                              reviews userPlaceNote  \
# 0  [{'name': 'Rosa Vazquez', 'text': None, 'textT...          None
# 1  [{'name': 'NYC Z', 'text': 'It's a shame that ...          None
# 2  [{'name': 'Shota Iyobe', 'text': None, 'textTr...          None
# 3  [{'name': 'Deborah Riehl', 'text': 'Looked qua...          None
# 4  [{'name': 'P. Martin', 'text': 'Dinner at the ...          None
#
#   restaurantData ownerUpdates
# 0             {}           []
# 1             {}           []
# 2             {}           []
# 3             {}           []
# 4             {}           []
#
# [5 rows x 71 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 10)      # Limit rows to avoid long output

# View the DataFrame
print(df.head())
# Out:
#                                  searchString  rank  \
# 0                    Michelin restaurants NYC    31
# 1  Michelin-starred restaurants New York City    32
# 2  Michelin-starred restaurants New York City    29
# 3                    Michelin restaurants NYC    88
# 4                    Michelin restaurants NYC    86
#
#                                        searchPageUrl searchPageLoadedUrl  \
# 0  https://www.google.com/maps/search/Michelin%20...                None
# 1  https://www.google.com/maps/search/Michelin-st...                None
# 2  https://www.google.com/maps/search/Michelin-st...                None
# 3  https://www.google.com/maps/search/Michelin%20...                None
# 4  https://www.google.com/maps/search/Michelin%20...                None
#
#    isAdvertisement                     title subTitle  \
# 0            False            Phil-Am Kusina     None
# 1            False              H & L Bagels     None
# 2            False        Coszcal De Allende     None
# 3            False                    E.A.T.     None
# 4            False  Dowling's at The Carlyle     None
#
#                                          description   price  \
# 0  Casual restaurant cooking up traditional Filip...  $10–20
# 1                                               None   $1–10
# 2                                               None  $30–50
# 3  Counter-serve outlet for breakfast and coffee,...  $30–50
# 4                                               None   $100+
#
#           categoryName                                     address  \
# 0  Filipino restaurant  556 Tompkins Ave., Staten Island, NY 10305
# 1           Bagel shop            8818 3rd Ave, Brooklyn, NY 11209
# 2   Mexican restaurant            7506 3rd Ave, Brooklyn, NY 11209
# 3  American restaurant        1064 Madison Ave, New York, NY 10028
# 4           Restaurant            35 E 76th St, New York, NY 10021
#
#     neighborhood             street           city postalCode     state  \
# 0       Rosebank  556 Tompkins Ave.  Staten Island      10305  New York
# 1  Fort Hamilton       8818 3rd Ave       Brooklyn      11209  New York
# 2      Bay Ridge       7506 3rd Ave       Brooklyn      11209  New York
# 3      Manhattan   1064 Madison Ave       New York      10028  New York
# 4      Manhattan       35 E 76th St       New York      10021  New York
#
#   countryCode                                            website  \
# 0          US                       http://www.philamkusina.com/
# 1          US                                               None
# 2          US                              http://coszcalbk.com/
# 3          US  https://e-a-t.nyc/?utm_medium=local&utm_source...
# 4          US  https://www.rosewoodhotels.com/en/the-carlyle-...
#
#             phone phoneUnformatted  claimThisBusiness  \
# 0  (718) 727-3663     +17187273663              False
# 1  (718) 748-6626     +17187486626               True
# 2  (718) 921-3523     +17189213523              False
# 3  (212) 772-0022     +12127720022              False
# 4  (212) 570-7192     +12125707192              False
#
#                                   location locatedIn  \
# 0   {'lat': 40.6124623, 'lng': -74.071427}      None
# 1  {'lat': 40.6216254, 'lng': -74.0320368}      None
# 2  {'lat': 40.6313072, 'lng': -74.0281532}      None
# 3  {'lat': 40.7773172, 'lng': -73.9616247}      None
# 4  {'lat': 40.7744222, 'lng': -73.9631514}      None
#
#                           plusCode  \
# 0  JW6H+XC Staten Island, New York
# 1       JXC9+M5 Brooklyn, New York
# 2       JXJC+GP Brooklyn, New York
# 3                 Q2GQ+W9 New York
# 4                 Q2FP+QP New York
#
#                                                 menu  totalScore  \
# 0                                               None         4.7
# 1                                               None         4.6
# 2  https://order.toasttab.com/online/coszcal-de-a...         4.4
# 3  http://places.singleplatform.com/e-a-t/menu?re...         2.9
# 4                                               None         3.7
#
#    permanentlyClosed  temporarilyClosed                      placeId  \
# 0              False              False  ChIJDYD92atPwokRlN30x0vubIk
# 1              False              False  ChIJ7_q38YpPwokRkCP4WrrKyyE
# 2              False              False  ChIJi5qu7VZFwokR-1Q2ILFTyuM
# 3              False              False  ChIJ8aQDcJZYwokRyPVIfqjkazY
# 4              False              False  ChIJIaES4oRZwokRELx8tCqNYOg
#
#                                   categories  \
# 0                      [Filipino restaurant]
# 1         [Bagel shop, Breakfast restaurant]
# 2  [Mexican restaurant, Delivery Restaurant]
# 3                [American restaurant, Cafe]
# 4                               [Restaurant]
#
#                                      fid                   cid  reviewsCount  \
# 0  0x89c24fabd9fd800d:0x896cee4bc7f4dd94   9902551689925549460           320
# 1  0x89c24f8af1b7faef:0x21cbcaba5af82390   2435262925262824336           276
# 2  0x89c24556edae9a8b:0xe3ca53b1203654fb  16414023812119942395           331
# 3  0x89c258967003a4f1:0x366be4a87e48f5c8   3921479312880498120          1061
# 4  0x89c25984e212a121:0xe8608d2ab47cbc10  16744538629119720464            61
#
#                                  reviewsDistribution  imagesCount  \
# 0  {'oneStar': 6, 'twoStar': 4, 'threeStar': 8, '...          487
# 1  {'oneStar': 4, 'twoStar': 4, 'threeStar': 14, ...           89
# 2  {'oneStar': 25, 'twoStar': 9, 'threeStar': 15,...          217
# 3  {'oneStar': 372, 'twoStar': 83, 'threeStar': 1...          384
# 4  {'oneStar': 9, 'twoStar': 7, 'threeStar': 9, '...           99
#
#                                      imageCategories  \
# 0  [All, Menu, Videos, Food & drink, Vibe, Halo-h...
# 1  [All, Menu, Videos, Food & drink, Vibe, Bagel,...
# 2  [All, Menu, Videos, Food & drink, Vibe, Taco, ...
# 3  [All, Menu, Videos, Food & drink, Vibe, Coffee...
# 4  [All, Menu, Food & drink, Vibe, Street View & ...
#
#                   scrapedAt  \
# 0  2024-12-16T02:34:38.457Z
# 1  2024-12-16T02:34:38.200Z
# 2  2024-12-16T02:34:42.372Z
# 3  2024-12-16T02:34:53.781Z
# 4  2024-12-16T02:35:07.505Z
#
#                                      reserveTableUrl googleFoodUrl hotelStars  \
# 0                                               None          None       None
# 1                                               None          None       None
# 2  https://www.google.com/maps/reserve/v/dine/c/P...          None       None
# 3                                               None          None       None
# 4  https://www.google.com/maps/reserve/v/dine/c/4...          None       None
#
#   hotelDescription checkInDate checkOutDate similarHotelsNearby  \
# 0             None        None         None                None
# 1             None        None         None                None
# 2             None        None         None                None
# 3             None        None         None                None
# 4             None        None         None                None
#
#   hotelReviewSummary hotelAds popularTimesLiveText  popularTimesLivePercent  \
# 0               None       []                 None                      NaN
# 1               None       []                 None                      NaN
# 2               None       []             Not busy                      0.0
# 3               None       []                 None                      NaN
# 4               None       []                  NaN                      NaN
#
#                                popularTimesHistogram  \
# 0  {'Su': [{'hour': 6, 'occupancyPercent': 0}, {'...
# 1  {'Su': [{'hour': 4, 'occupancyPercent': 0}, {'...
# 2  {'Su': [{'hour': 6, 'occupancyPercent': 0}, {'...
# 3  {'Su': [{'hour': 6, 'occupancyPercent': 0}, {'...
# 4                                                NaN
#
#                                         openingHours  \
# 0  [{'day': 'Monday', 'hours': 'Closed'}, {'day':...
# 1  [{'day': 'Monday', 'hours': '5 AM to 3:45 PM'}...
# 2  [{'day': 'Monday', 'hours': 'Closed'}, {'day':...
# 3  [{'day': 'Monday', 'hours': '8 AM to 6 PM'}, {...
# 4  [{'day': 'Monday', 'hours': '7 AM to 10 PM'}, ...
#
#                                     peopleAlsoSearch placesTags  \
# 0  [{'category': 'People also search for', 'title...         []
# 1  [{'category': 'People also search for', 'title...         []
# 2  [{'category': 'People also search for', 'title...         []
# 3  [{'category': 'People also search for', 'title...         []
# 4  [{'category': 'People also search for', 'title...         []
#
#                                          reviewsTags  \
# 0  [{'title': 'pork', 'count': 17}, {'title': 'pr...
# 1  [{'title': 'prices', 'count': 19}, {'title': '...
# 2  [{'title': 'margarita', 'count': 22}, {'title'...
# 3  [{'title': 'deli', 'count': 27}, {'title': 'th...
# 4  [{'title': 'price', 'count': 14}, {'title': 'd...
#
#                                       additionalInfo gasPrices  \
# 0  {'Service options': [{'Delivery': True}, {'Tak...        []
# 1  {'Service options': [{'Takeout': True}], 'Acce...        []
# 2  {'Service options': [{'Outdoor seating': True}...        []
# 3  {'Service options': [{'Outdoor seating': True}...        []
# 4  {'Service options': [{'Dine-in': True}, {'Deli...        []
#
#                                  questionsAndAnswers  \
# 0  [{'question': 'Do you serve alcohol?', 'answer...
# 1  [{'question': 'Does H and H deliver? ', 'answe...
# 2  [{'question': 'Till what time is Happy Hour', ...
# 3                                                 []
# 4                                                 []
#
#                                 updatesFromCustomers  \
# 0  {'text': 'Sisig Baboy', 'language': 'fil', 'po...
# 1  {'text': 'By far the best breakfast sandwich I...
# 2  {'text': 'The food and drink were extremely go...
# 3                                               None
# 4                                               None
#
#                                                  url  \
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...
#
#                                             imageUrl          kgmid  \
# 0  https://lh5.googleusercontent.com/p/AF1QipOVCz...  /g/11b6xlr3s9
# 1  https://lh5.googleusercontent.com/p/AF1QipNTRd...    /g/1tcygck9
# 2  https://lh5.googleusercontent.com/p/AF1QipNn8o...  /g/11bbrh0shd
# 3  https://lh5.googleusercontent.com/p/AF1QipMY0s...  /g/11cks906rh
# 4  https://lh5.googleusercontent.com/p/AF1QipPwsQ...  /g/11nxv7_wvk
#
#   webResults parentPlaceUrl  \
# 0         []           None
# 1         []           None
# 2         []           None
# 3         []           None
# 4         []           None
#
#                                tableReservationLinks bookingLinks  \
# 0                                                 []           []
# 1                                                 []           []
# 2  [{'name': 'resy.com', 'url': 'https://resy.com...           []
# 3                                                 []           []
# 4  [{'name': 'resy.com', 'url': 'https://resy.com...           []
#
#                                              orderBy images  \
# 0  [{'name': 'Seamless', 'orderUrl': 'https://www...   None
# 1                                                 []   None
# 2  [{'name': 'Toast Online Ordering', 'orderUrl':...   None
# 3  [{'name': 'Storefront by DoorDash', 'orderUrl'...   None
# 4                                                 []   None
#
#                                            imageUrls  \
# 0  [https://lh5.googleusercontent.com/p/AF1QipOVC...
# 1  [https://lh5.googleusercontent.com/p/AF1QipNTR...
# 2  [https://lh5.googleusercontent.com/p/AF1QipNn8...
# 3  [https://lh5.googleusercontent.com/p/AF1QipMY0...
# 4  [https://lh5.googleusercontent.com/p/AF1QipPws...
#
#                                              reviews userPlaceNote  \
# 0  [{'name': 'Rosa Vazquez', 'text': None, 'textT...          None
# 1  [{'name': 'NYC Z', 'text': 'It's a shame that ...          None
# 2  [{'name': 'Shota Iyobe', 'text': None, 'textTr...          None
# 3  [{'name': 'Deborah Riehl', 'text': 'Looked qua...          None
# 4  [{'name': 'P. Martin', 'text': 'Dinner at the ...          None
#
#   restaurantData ownerUpdates
# 0             {}           []
# 1             {}           []
# 2             {}           []
# 3             {}           []
# 4             {}           []

# %% [markdown]
# ## Select the columns we need

# %%
# List of desired columns
desired_columns = [
    "title", "price", "categoryName", "address", "neighborhood",
    "street", "city", "postalCode", "state", "location",
    "totalScore", "reviewsCount", "url", "reviews"
]

# Filter the DataFrame to keep only the desired columns
df_selected = df[desired_columns]

# Display the resulting DataFrame
print(df_selected.head())
# Out:
#                       title   price         categoryName  \
# 0            Phil-Am Kusina  $10–20  Filipino restaurant
# 1              H & L Bagels   $1–10           Bagel shop
# 2        Coszcal De Allende  $30–50   Mexican restaurant
# 3                    E.A.T.  $30–50  American restaurant
# 4  Dowling's at The Carlyle   $100+           Restaurant
#
#                                       address   neighborhood  \
# 0  556 Tompkins Ave., Staten Island, NY 10305       Rosebank
# 1            8818 3rd Ave, Brooklyn, NY 11209  Fort Hamilton
# 2            7506 3rd Ave, Brooklyn, NY 11209      Bay Ridge
# 3        1064 Madison Ave, New York, NY 10028      Manhattan
# 4            35 E 76th St, New York, NY 10021      Manhattan
#
#               street           city postalCode     state  \
# 0  556 Tompkins Ave.  Staten Island      10305  New York
# 1       8818 3rd Ave       Brooklyn      11209  New York
# 2       7506 3rd Ave       Brooklyn      11209  New York
# 3   1064 Madison Ave       New York      10028  New York
# 4       35 E 76th St       New York      10021  New York
#
#                                   location  totalScore  reviewsCount  \
# 0   {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 1  {'lat': 40.6216254, 'lng': -74.0320368}         4.6           276
# 2  {'lat': 40.6313072, 'lng': -74.0281532}         4.4           331
# 3  {'lat': 40.7773172, 'lng': -73.9616247}         2.9          1061
# 4  {'lat': 40.7744222, 'lng': -73.9631514}         3.7            61
#
#                                                  url  \
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...
#
#                                              reviews
# 0  [{'name': 'Rosa Vazquez', 'text': None, 'textT...
# 1  [{'name': 'NYC Z', 'text': 'It's a shame that ...
# 2  [{'name': 'Shota Iyobe', 'text': None, 'textTr...
# 3  [{'name': 'Deborah Riehl', 'text': 'Looked qua...
# 4  [{'name': 'P. Martin', 'text': 'Dinner at the ...

# %% [markdown]
# ## Refine the review column

# %%
# Explode the 'reviews' column to split lists into rows
df_exploded = df_selected.explode('reviews', ignore_index=True)

# Extract 'text' from the dictionary in each exploded row
df_exploded['review_text'] = df_exploded['reviews'].apply(
    lambda x: x.get('text') if isinstance(x, dict) else None
)

# Drop the original 'reviews' column (optional)
df_final = df_exploded.drop(columns=['reviews'])

# Filter out rows where 'review_text' is None
df_final = df_final.dropna(subset=['review_text'])

print(df_final)
# Out:
#                 title   price         categoryName  \
# 1      Phil-Am Kusina  $10–20  Filipino restaurant
# 2      Phil-Am Kusina  $10–20  Filipino restaurant
# 3      Phil-Am Kusina  $10–20  Filipino restaurant
# 4      Phil-Am Kusina  $10–20  Filipino restaurant
# 5      Phil-Am Kusina  $10–20  Filipino restaurant
# ...               ...     ...                  ...
# 17342         Mao Mao  $20–30      Thai restaurant
# 17344         Mao Mao  $20–30      Thai restaurant
# 17347         Mao Mao  $20–30      Thai restaurant
# 17349         Mao Mao  $20–30      Thai restaurant
# 17350         Mao Mao  $20–30      Thai restaurant
#
#                                           address        neighborhood  \
# 1      556 Tompkins Ave., Staten Island, NY 10305            Rosebank
# 2      556 Tompkins Ave., Staten Island, NY 10305            Rosebank
# 3      556 Tompkins Ave., Staten Island, NY 10305            Rosebank
# 4      556 Tompkins Ave., Staten Island, NY 10305            Rosebank
# 5      556 Tompkins Ave., Staten Island, NY 10305            Rosebank
# ...                                           ...                 ...
# 17342           1000 Broadway, Brooklyn, NY 11221  Bedford-Stuyvesant
# 17344           1000 Broadway, Brooklyn, NY 11221  Bedford-Stuyvesant
# 17347           1000 Broadway, Brooklyn, NY 11221  Bedford-Stuyvesant
# 17349           1000 Broadway, Brooklyn, NY 11221  Bedford-Stuyvesant
# 17350           1000 Broadway, Brooklyn, NY 11221  Bedford-Stuyvesant
#
#                   street           city postalCode     state  \
# 1      556 Tompkins Ave.  Staten Island      10305  New York
# 2      556 Tompkins Ave.  Staten Island      10305  New York
# 3      556 Tompkins Ave.  Staten Island      10305  New York
# 4      556 Tompkins Ave.  Staten Island      10305  New York
# 5      556 Tompkins Ave.  Staten Island      10305  New York
# ...                  ...            ...        ...       ...
# 17342      1000 Broadway       Brooklyn      11221  New York
# 17344      1000 Broadway       Brooklyn      11221  New York
# 17347      1000 Broadway       Brooklyn      11221  New York
# 17349      1000 Broadway       Brooklyn      11221  New York
# 17350      1000 Broadway       Brooklyn      11221  New York
#
#                                      location  totalScore  reviewsCount  \
# 1      {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 2      {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 3      {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 4      {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 5      {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# ...                                       ...         ...           ...
# 17342  {'lat': 40.695799, 'lng': -73.9334587}         4.4           344
# 17344  {'lat': 40.695799, 'lng': -73.9334587}         4.4           344
# 17347  {'lat': 40.695799, 'lng': -73.9334587}         4.4           344
# 17349  {'lat': 40.695799, 'lng': -73.9334587}         4.4           344
# 17350  {'lat': 40.695799, 'lng': -73.9334587}         4.4           344
#
#                                                      url  \
# 1      https://www.google.com/maps/search/?api=1&quer...
# 2      https://www.google.com/maps/search/?api=1&quer...
# 3      https://www.google.com/maps/search/?api=1&quer...
# 4      https://www.google.com/maps/search/?api=1&quer...
# 5      https://www.google.com/maps/search/?api=1&quer...
# ...                                                  ...
# 17342  https://www.google.com/maps/search/?api=1&quer...
# 17344  https://www.google.com/maps/search/?api=1&quer...
# 17347  https://www.google.com/maps/search/?api=1&quer...
# 17349  https://www.google.com/maps/search/?api=1&quer...
# 17350  https://www.google.com/maps/search/?api=1&quer...
#
#                                              review_text
# 1      I bring my family and friends here. Excellent ...
# 2      I usually enjoy Filipino lechon kawali (fried ...
# 3      Amazing food and amazing service. Every time I...
# 4      What a gem in Staten Island. The food was abso...
# 5      This is THE best tasting Philippines Restauran...
# ...                                                  ...
# 17342  An amazing restaurant in everything ! The envi...
# 17344  This place is definitely a unique experience, ...
# 17347  Not many vegetarian options for a Thai place, ...
# 17349  The food is so good and authentic but why are ...
# 17350  Come for the ambiance, snacks, & unique atmosp...
#
# [12050 rows x 14 columns]

# %% [markdown]
# ## Convert location column into geometry

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

df_selected['latitude'] = df_selected['location'].apply(lambda x: x.get('lat') if isinstance(x, dict) else None)
df_selected['longitude'] = df_selected['location'].apply(lambda x: x.get('lng') if isinstance(x, dict) else None)

geometry = [Point(lon, lat) for lon, lat in zip(df_selected['longitude'], df_selected['latitude'])]

gdf = gpd.GeoDataFrame(df_selected, geometry=geometry, crs="EPSG:4326")  # WGS84 Coordinate System

print(gdf.head())
# Out:
#                       title   price         categoryName  \
# 0            Phil-Am Kusina  $10–20  Filipino restaurant
# 1              H & L Bagels   $1–10           Bagel shop
# 2        Coszcal De Allende  $30–50   Mexican restaurant
# 3                    E.A.T.  $30–50  American restaurant
# 4  Dowling's at The Carlyle   $100+           Restaurant
#
#                                       address   neighborhood  \
# 0  556 Tompkins Ave., Staten Island, NY 10305       Rosebank
# 1            8818 3rd Ave, Brooklyn, NY 11209  Fort Hamilton
# 2            7506 3rd Ave, Brooklyn, NY 11209      Bay Ridge
# 3        1064 Madison Ave, New York, NY 10028      Manhattan
# 4            35 E 76th St, New York, NY 10021      Manhattan
#
#               street           city postalCode     state  \
# 0  556 Tompkins Ave.  Staten Island      10305  New York
# 1       8818 3rd Ave       Brooklyn      11209  New York
# 2       7506 3rd Ave       Brooklyn      11209  New York
# 3   1064 Madison Ave       New York      10028  New York
# 4       35 E 76th St       New York      10021  New York
#
#                                   location  totalScore  reviewsCount  \
# 0   {'lat': 40.6124623, 'lng': -74.071427}         4.7           320
# 1  {'lat': 40.6216254, 'lng': -74.0320368}         4.6           276
# 2  {'lat': 40.6313072, 'lng': -74.0281532}         4.4           331
# 3  {'lat': 40.7773172, 'lng': -73.9616247}         2.9          1061
# 4  {'lat': 40.7744222, 'lng': -73.9631514}         3.7            61
#
#                                                  url  \
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...
#
#                                              reviews   latitude  longitude  \
# 0  [{'name': 'Rosa Vazquez', 'text': None, 'textT...  40.612462 -74.071427
# 1  [{'name': 'NYC Z', 'text': 'It's a shame that ...  40.621625 -74.032037
# 2  [{'name': 'Shota Iyobe', 'text': None, 'textTr...  40.631307 -74.028153
# 3  [{'name': 'Deborah Riehl', 'text': 'Looked qua...  40.777317 -73.961625
# 4  [{'name': 'P. Martin', 'text': 'Dinner at the ...  40.774422 -73.963151
#
#                      geometry
# 0  POINT (-74.07143 40.61246)
# 1  POINT (-74.03204 40.62163)
# 2  POINT (-74.02815 40.63131)
# 3  POINT (-73.96162 40.77732)
# 4  POINT (-73.96315 40.77442)
# /var/folders/q7/ww3mcfxj1pv1181n2srlnm780000gn/T/ipykernel_27933/3357681030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['latitude'] = df_selected['location'].apply(lambda x: x.get('lat') if isinstance(x, dict) else None)
# /var/folders/q7/ww3mcfxj1pv1181n2srlnm780000gn/T/ipykernel_27933/3357681030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['longitude'] = df_selected['location'].apply(lambda x: x.get('lng') if isinstance(x, dict) else None)

# %%
df_final['latitude'] = df_final['location'].apply(lambda x: x.get('lat') if isinstance(x, dict) else None)
df_final['longitude'] = df_final['location'].apply(lambda x: x.get('lng') if isinstance(x, dict) else None)

geometry = [Point(lon, lat) for lon, lat in zip(df_final['longitude'], df_final['latitude'])]

df_final = gpd.GeoDataFrame(df_final, geometry=geometry, crs="EPSG:4326")

# %%
output_path = "/Users/luoxiaoyi/Downloads/24fall-python-final-proposal-kuma_chloe_wenjun_finalproposal-main/pythonfinal/data/restaurants_reviews_final.geojson"
df_final.to_file(output_path, driver="GeoJSON")
print(f"File saved to: {output_path}")
# Out:
# File saved to: /Users/luoxiaoyi/Downloads/24fall-python-final-proposal-kuma_chloe_wenjun_finalproposal-main/pythonfinal/data/restaurants_reviews_final.geojson

# %% [markdown]
# ## Interactive Map of Top-Rated Restaurants in New York City
# This interactive map showcases a curated selection of restaurants across New York City, displaying key details such as name, address, and overall rating. Each marker represents a restaurant and provides additional information, including its location and review scores, to help explore dining options throughout the city.

# %%
import folium
from shapely.geometry import Point

map_center = [gdf['latitude'].mean(), gdf['longitude'].mean()] 
m = folium.Map(location=map_center, zoom_start=12)

for _, row in gdf.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(f"<b>{row['title']}</b><br>{row['address']}<br>Score: {row['totalScore']}", max_width=300),
        tooltip=row['title']
    ).add_to(m)

m.save("interactive_restaurants_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14081dc3201fce14094d99c3c7f9217e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14081dc3201fce14094d99c3c7f9217e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14081dc3201fce14094d99c3c7f9217e = L.map(
#                 &quot;map_14081dc3201fce14094d99c3c7f9217e&quot;,
#                 {
#                     center: [40.74449474277778, -73.94425158888887],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_335c9b021ac2bdff112c726ba3d5f3ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_335c9b021ac2bdff112c726ba3d5f3ad.addTo(map_14081dc3201fce14094d99c3c7f9217e);
#
#
#             var marker_a26fbd254c8ee9db227ea13b4aa9fc67 = L.marker(
#                 [40.6124623, -74.071427],
#                 {}
#             ).addTo(map_14081dc3201fce14094d99c3c7f9217e);
#
#
#         var popup_9a82b8c55c71b7efc3972f5b8a2e76b4 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5b81159d095ff24bcc56e9cc5023f026 = $(`&lt;div id=&quot;html_5b81159d095ff24bcc56e9cc5023f026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Phil-Am Kusina&lt;/b&gt;&lt;br&gt;556 Tompkins Ave., Staten Island, NY 10305&lt;br&gt;Score: 4.7&lt;/div&gt;`)[0];
#                 popup_9a82b8c55c71b7efc3972f5b8a2e76b4.setContent(html_5b81159d095ff24bcc56e9cc5023f026);
#
#
#
#         marker_a26fbd254c8ee9db227ea13b4aa9fc67.bindPopup(popup_9a82b8c55c71b7efc3972f5b8a2e76b4)
#         ;
#
#
#
#
#             marker_a26fbd254c8ee9db227ea13b4aa9fc67.bindTooltip(
#                 `&lt;div&gt;
#                      Phil-Am Kusina
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_172457cd68e3b0c600e867ed21cf3bda = L.marker(
#                 [40.6216254, -74.0320368],
#                 {}
#             ).addTo(map_14081dc3201fce14094d99c3c7f9217e);
#
#
#         var popup_3592b90e0cb2f0fa21ecd22bfabd27c9 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a5f481fc26d1257d3b3224ffbb1ebb0f = $(`&lt;div id=&quot;html_a5f481fc26d1257d3b3224ffbb1ebb0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;H &amp; L Bagels&lt;/b&gt;&lt;br&gt;8818 3rd Ave, Brooklyn, NY 11209&lt;br&gt;Score: 4.6&lt;/div&gt;`)[0];
#                 popup_3592b90e0cb2f0fa21ecd22bfabd27c9.setContent(html_a5f481fc26d1257d3b3224ffbb1ebb0f);
#
#
#
#         marker_172457cd68e3b0c600e867ed21cf3bda.bindPopup(popup_3592b90e0cb2f0fa21ecd22bfabd27c9)
#         ;
#
#
#
#
#             marker_172457cd68e3b0c600e867ed21cf3bda.bindTooltip(
#                 `&lt;div&gt;
#                      H &amp; L Bagels
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_50883eb40ca13b5944ffdb8251cd7c46 = L.marker(
#                 [40.6313072, -74.0281532],
#                 {}
#             ).addTo(map_14081dc3201fce14094d99c3c7f9217e);
#
#
#         var popup_605627ce5440b663603668a8e78b3a05 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3b21472f739591dc27f92260bd259a9a = $(`&lt;div id=&quot;html_3b21472f739591dc27f92260bd259a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Coszcal De Allende&lt;/b&gt;&lt;br&gt;7506 3rd Ave, Brooklyn, NY 11209&lt;br&gt;Score: 4.4&lt;/div&gt;`)[0];
#                 popup_605627ce5440b663603668a8e78b3a05.setContent(html_3b21472f739591dc27f92260bd259a9a);
#
#
#
#         marker_50883eb40ca13b5944ffdb8251cd7c46.bindPopup(popup_605627ce5440b663603668a8e78b3a05)
#         ;
#
#
#
#
#             marker_50883eb40ca13b5944ffdb8251cd7c46.bindTooltip(
#                 `&lt;div&gt;
#                      Coszcal De Allende
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3211f8d4060cb76e7a55f18b93d5e781 = L.marker(
#                 [40.7773172, -73.9616247],
#                 {}
#             ).addTo(map_14081dc3201fce14094d99c3c7f9217e);
#
#
#         var popup_a98122ac4a68c95ca7a9fce58f9f510c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_2d95effdfb3a0be41882fa54e3b3d83d = $(`&lt;div id=&quot;html_2d95effdfb3a0be41882fa54e3b3d83d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;E.A.T.&lt;/b&gt;&lt;br&gt;1064 Madison Ave, New York, NY 10028&lt;br&gt;Score: 2.9&lt;/div&gt;`)[0];
#                 popup_a98122ac4a68c95ca7a9fce58f9f510c.setContent(html_2d95effdfb3a0be41882fa54e3b3d83d);
#
#
#
#         marker_3211f8d4060cb76e7a55f18b93d5e781.bindPopup(popup_a98122ac4a68c95ca

# %%
output_path = "/Users/luoxiaoyi/Downloads/24fall-python-final-proposal-kuma_chloe_wenjun_finalproposal-main/pythonfinal/data/restaurants_info.geojson"
gdf.to_file(output_path, driver="GeoJSON")

print(f"File saved to: {output_path}")
# Out:
# File saved to: /Users/luoxiaoyi/Downloads/24fall-python-final-proposal-kuma_chloe_wenjun_finalproposal-main/pythonfinal/data/restaurants_info.geojson

# %%
print("Unique values in 'price':", df_selected['price'].unique())
# Out:
# Unique values in 'price': ['$10–20' '$1–10' '$30–50' '$100+' '$20–30' '$50–100' '$$$' '$$' None
#  '$$$$' '$']
