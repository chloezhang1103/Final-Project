# %%
# !pip install geopandas folium shapely matplotlib
# Out:
# Requirement already satisfied: geopandas in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: folium in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: shapely in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (2.0.6)
# Requirement already satisfied: matplotlib in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: fiona>=1.8.21 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: numpy>=1.22 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: packaging in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.4.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: branca>=0.6.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (24.2.0)
# Requirement already satisfied: certifi in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2024.7.4)
# Requirement already satisfied: click~=8.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhuzhu/miniforge3/lib/python3.10/site-packages (from requests->folium) (2.2.1)

# %%
import folium

# 计算数据中心点
center_lat = (40.542868 + 40.8635587) / 2
center_lon = (-74.142427 + -73.7846917) / 2

# 创建地图
m = folium.Map(location=[center_lat, center_lon], zoom_start=12, tiles="CartoDB Positron")

# 添加点数据
for idx, row in gdf.iterrows():
    # 数据格式处理
    romantic_distance = round(row['nearest_romantic_distance'], 2)
    noise_count = int(row['noise_count'])
    parking_distance = round(row['nearest_parking_distance'], 2)
    
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=folium.Popup(f"""
            <b style="color:orange; font-size:14px;">{row['title']}</b><br>
            <b>Category:</b> {row['categoryName']}<br>
            <b>Address:</b> {row['address']}<br>
            <b>Parking Distance:</b> {parking_distance} m<br>
            <b>Bus Stops (500m):</b> {row['bus_count_500m']}<br>
            <b>Subways (500m):</b> {row['subway_count_500m']}<br>
            <b>Transport Score:</b> {row['public_transport_score']}<br>
            <b>Romantic Spot Distance:</b> {romantic_distance} m<br>
            <b>Noise Count:</b> {noise_count}<br>
            <b>Median Income:</b> ${row['Median_Household_Income']}<br>
            <b>Price Rank:</b> {row['price_cleaned']}
            """, max_width=300),
        icon=folium.Icon(color="red", icon="cutlery", prefix="fa")  # 更换为餐厅的 cutlery 图标
    ).add_to(m)

# 显示地图
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa96364a8e26026292952fc02763c19a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa96364a8e26026292952fc02763c19a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa96364a8e26026292952fc02763c19a = L.map(
#                 &quot;map_aa96364a8e26026292952fc02763c19a&quot;,
#                 {
#                     center: [40.70321335, -73.96355935],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a525185d282017c615db2380f8111de = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0a525185d282017c615db2380f8111de.addTo(map_aa96364a8e26026292952fc02763c19a);
#
#
#             var marker_9a13dbdff0463f2ab2bc3d01d079c5e6 = L.marker(
#                 [40.61246230000001, -74.071427],
#                 {}
#             ).addTo(map_aa96364a8e26026292952fc02763c19a);
#
#
#             var icon_6530107231e1f76df60e2dd62d065f88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a13dbdff0463f2ab2bc3d01d079c5e6.setIcon(icon_6530107231e1f76df60e2dd62d065f88);
#
#
#         var popup_9b3ae31c1f9c313c17eddc5dfb3661bd = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e5f77a94a31b23ee12d782f0bcdd61ab = $(`&lt;div id=&quot;html_e5f77a94a31b23ee12d782f0bcdd61ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;b style=&quot;color:orange; font-size:14px;&quot;&gt;Phil-Am Kusina&lt;/b&gt;&lt;br&gt;             &lt;b&gt;Category:&lt;/b&gt; Filipino restaurant&lt;br&gt;             &lt;b&gt;Address:&lt;/b&gt; 556 Tompkins Ave., Staten Island, NY 10305&lt;br&gt;             &lt;b&gt;Parking Distance:&lt;/b&gt; 23.4 m&lt;br&gt;             &lt;b&gt;Bus Stops (500m):&lt;/b&gt; 1&lt;br&gt;             &lt;b&gt;Subways (500m):&lt;/b&gt; 0&lt;br&gt;             &lt;b&gt;Transport Score:&lt;/b&gt; 1&lt;br&gt;             &lt;b&gt;Romantic Spot Distance:&lt;/b&gt; 284.55 m&lt;br&gt;             &lt;b&gt;Noise Count:&lt;/b&gt; 7&lt;br&gt;             &lt;b&gt;Median Income:&lt;/b&gt; $85183.0&lt;br&gt;             &lt;b&gt;Price Rank:&lt;/b&gt; 15.0             &lt;/div&gt;`)[0];
#                 popup_9b3ae31c1f9c313c17eddc5dfb3661bd.setContent(html_e5f77a94a31b23ee12d782f0bcdd61ab);
#
#
#
#         marker_9a13dbdff0463f2ab2bc3d01d079c5e6.bindPopup(popup_9b3ae31c1f9c313c17eddc5dfb3661bd)
#         ;
#
#
#
#
#             var marker_82aa99392ed9d2cbad9457ee368a4c76 = L.marker(
#                 [40.62162539999998, -74.0320368],
#                 {}
#             ).addTo(map_aa96364a8e26026292952fc02763c19a);
#
#
#             var icon_49ac175210b8640f1ebdfa9fbd1b4f7d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_82aa99392ed9d2cbad9457ee368a4c76.setIcon(icon_49ac175210b8640f1ebdfa9fbd1b4f7d);
#
#
#         var popup_80e19d59ab4bc7837cf426aa9677048d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_cb6cfc5ec2753e43fa377543a5cde17a = $(`&lt;div id=&quot;html_cb6cfc5ec2753e43fa377543a5cde17a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;b style=&quot;color:orange; font-size:14px;&quot;&gt;H &amp; L Bagels&lt;/b&gt;&lt;br&gt;             &lt;b&gt;Category:&lt;/b&gt; Bagel shop&lt;br&gt;             &lt;b&gt;Address:&lt;/b&gt; 8818 3rd Ave, Brooklyn, NY 11209&lt;br&gt;             &lt;b&gt;Parking Distance:&lt;/b&gt; 131.47 m&lt;br&gt;             &lt;b&gt;Bus Stops (500m):&lt;/b&gt; 3&lt;br&gt;             &lt;b&gt;Subways (500m):&lt;/b&gt; 1&lt;br&gt;             &lt;b&gt;Transport Score:&lt;/b&gt; 6&lt;br&gt;             &lt;b&gt;Romantic Spot Distance:&lt;/b&gt; 404.13 m&lt;br&gt;             &lt;b&gt;Noise Count:&lt;/b&gt; 508&lt;br&gt;             &lt;b&gt;Median Income:&lt;/b&gt; $86582.0&lt;br&gt;             &lt;b&gt;Price Rank:&lt;/b&gt; 5.5             &lt;/div&gt;`)[0];
#                 popup_80e19d59ab4bc7837cf426aa9677048d.setContent(html_cb6cfc5ec2753e43fa377543a5cde17a);
#
#
#
#         marker_82aa99392ed9d2cbad9457ee368a4c76.bindPopup(popup_80e19d59ab4bc7837cf426aa9677048d)
#         ;
#
#
#
#
#             var marker_a2f3fbc1fe0d768600db47f355ed6d5f = L.marker(

# %%
output_file = "restaurant_map.html"
m.save(output_file)
